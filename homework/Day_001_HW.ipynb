# %% [markdown]
# Day 1
# -作業1-
# Air quality in northern Taiwan
#
# 1-2:生活在北台灣，明顯感覺到近年空氣品質逐年惡化。然而為得到衡量空氣品質程度的客觀量化指標，尚須透過資料蒐集與整理及分析方可實現。
# 資料為台灣北部空品區 之 2018全年逐時資料。下載於行政院環境保護署「空氣品質監測網」，數據為全台北部地區共26個測站之及時偵測數值，因此資料來源客觀具公信力。
# 環保署空品資料下載網址：https://taqm.epa.gov.tw/taqm/tw/YearlyDataDownload.aspx
#
# 3.蒐集而來的資料來自於各測站逐時偵測數據，型態為各污染物之數值、風速風向雨量等。如下：
#
# SO2 - ppb - Sulfur dioxide
# CO - ppm - Carbon monoxide
# O3 - ppb - ozone
# PM10 - μg/m3 - Particulate matter
# PM2.5 - μg/m3 - Particulate matter
# NOx - ppb - Nitrogen oxides
# NO - ppb - Nitric oxide
# NO2 - ppb - Nitrogen dioxide
# AMB_TEMP - Celsius - Ambient air temperature
# RAINFALL - mm
# RH - % - Relative humidity
# WIND_SPEED - m/sec - The average of last ten minutes per hour
# WIND_DIREC - degress - The average of last ten minutes per hour
# WS_HR - m/sec - The average of hour
# WD_HR - degress - The average of hour
# PH_RAIN - PH - Acid rain
# RAIN_COND - μS/cm - Conductivity of acid rain
#
# 4.我想透過回歸方式(即MSE)評估本組資料即可得到不同程度空氣品質結果，結合汙染物對人體影響之知識，將能較有效率判斷空氣品質的嚴重程度。
# 另外亦可能找出資料中各參數之間的彼此相關性，結合其他背景知識(如地理季節產業近況等)，有望預測未來空氣品質狀況。對於應對甚至改善較能提出適當方針。

# %% [markdown]
# -作業2-
# 1.我認為提升業績意味著更高的載客率。假如現在業績有不足之處，可從減少空車率下手，亦即讓上線的車輛盡量處於有載客的狀態。
#
# 2.為達此目標，我規劃依照以下重點進行。
# 一、得到目前載客率、空車狀況(各時段及地區之數據)
# 二、得到熱點-「尖峰時段及地區」(取得搭乘需求最高的黃金時段及地區)，同時可納入該時段之時空情境，比方天氣以及是否有特殊展覽活動慶典等。
# 三、得到競爭車業之任何數據(比方說有哪些對象會是競爭者，他們的策略為何，我方載客率有沒有可能因為對方而受阻..等等)
# 四、整理資料並分析後，透過機器學習方可預測需求，透過人工智慧推薦線上司機適合的路線，進而達到新的配車策略。整體來說，便能集中火力在熱點黃金時段及地區(該時段增加配車)，配車於競爭對手少的時段及地區等。
# 資料可源自於自家車業的歷年數據，或各車業，如UBER之統計數據，交通部亦針對計程車營運狀況製作了調查報告可供參考。
#
# 3.資料蒐集型態應包含過去各地區對應時段之配車量、載客量、里程數、空車量及時間等，以及該時段地區之天氣、特殊活動慶典節日等資訊。
#
# 4.我想實際的驗證方法為，蒐集改善後之實際狀況(可為試運期間蒐集的)數據並與改善前計算其統計差異。
# 可藉由得到明顯的統計差異驗證原假設。

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 10.721

# %%
def mean_square_error(y, yp):
    mse=MSE=sum(y-yp)**2/len(y)
    return mse

MSE=mean_square_error(y, y_hat)
print("The Mean square error is %.3f" % (MSE))
# Out:
# The Mean square error is 296.766
